# %%
# Glorious workarounds for modules
import os
os.chdir("../..")
from invisoplanet_detection.statistics.stats import *

# %%
# 1D example
one_dimension = Likelihood(known_bodies=2, unknown_bodies=1,
                            parameters_filename="invisoplanet_detection/statistics/tests/ic_files/D_sun_jup_sat_2_1_1.json",
                            max_masses=[2.2 * 0.000285802], surrogate_points=7, num_iterations=200)

# %%
# Plot in 1D
one_dimension.set_eta(1)
one_dimension.plot_posterior("figures/one_dimensional.pdf", num=100, floor=None)

# %%
# 2D example
two_dimensions = Likelihood(known_bodies=1, unknown_bodies=2,
                            parameters_filename="invisoplanet_detection/statistics/tests/ic_files/H_sun_jup_sat_1_2_2.json",
                            max_masses=[1.5 * 1e-3, 1.5 * 1e-3], surrogate_points=5, num_iterations=2000)

# %%
# Plot in 2D
two_dimensions.set_eta(1)
two_dimensions.plot_posterior("figures/two_dimensional.pdf", num=100, floor=-0.002)
